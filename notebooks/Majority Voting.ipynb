# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=200)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from statistics import mode

m=2

preds = list(y_test[:2*m+1])
n_samples = X_test.shape[0]
final_preds = list(y_test[:2*m+1])

for i in range(m+1, n_samples-m-1, 1):
  vote = mode(preds)
  preds[m] = vote
  sample = X_test[i+m+1]
  sample_pred = lr.predict(sample.reshape((1, -1)))
  preds.pop(0)
  preds.append(sample_pred[0])
  final_preds.append(vote)

# %%
len(final_preds)
# Out:
# 99

# %%
y_test.shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test)
plt.plot(final_preds, color='red')
